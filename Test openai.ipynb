# %%
#%pip install langchain_openai
#dbutils.library.restartPython() # Restarts the Python process in a Databricks notebook

from langchain_openai import ChatOpenAI
import os

# Set up environment variables for the Databricks-managed endpoint
os.environ["OPENAI_API_KEY"] = " "
# or if using Azure OpenAI via Databricks
# os.environ["AZURE_OPENAI_API_KEY"] = "..."

# Initialize the Chat Model
# Initialize using Databricks serving endpoint
chat_model = ChatOpenAI(model="gpt-4o", 
                        openai_api_key=" ", 
                        openai_api_base="...")

messages = [HumanMessage(content="...")]
response = chat_model.invoke(messages)
print(response.content)
# Out:
# /databricks/python_shell/lib/dbruntime/autoreload/discoverability/autoreload_discoverability_hook.py:72: UserWarning: Spark Connect Session expired on the server. Please generate a new session by detaching and reattaching the compute if in a Databricks notebook or job or by calling DatabricksSession.builder.getOrCreate() if using Databricks Connect.
#   return orig_warn(*args, **kwargs)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-4882349176686397>, line 16
#       9 # or if using Azure OpenAI via Databricks
#      10 # os.environ["AZURE_OPENAI_API_KEY"] = "..."
#      11
#      12 # Initialize the Chat Model
#      13 # Initialize using Databricks serving endpoint
#      14 chat_model = ChatOpenAI(model="gpt-4o", openai_api_key="...", openai_api_base="...")
# ---> 16 messages = [HumanMessage(content="...")]
#      17 response = chat_model.invoke(messages)
# ...
